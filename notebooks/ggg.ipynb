# %%
# Dependencies
# !pip install torch_geometric
# !pip install rdkit
# Out:
# Collecting torch_geometric
#   Downloading torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.11.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2024.10.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (4.66.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch_geometric) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2024.8.30)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from multidict<7.0,>=4.5->aiohttp->torch_geometric) (4.12.2)
# Downloading torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 57.3 MB/s eta 0:00:00
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.6.1
# Collecting rdkit
#   Downloading rdkit-2024.3.6-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (11.0.0)
# Downloading rdkit-2024.3.6-cp310-cp310-manylinux_2_28_x86_64.whl (32.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 52.9 MB/s eta 0:00:00
# Installing collected packages: rdkit
# Successfully installed rdkit-2024.3.6

# %%
# Imports
import torch
from torch_geometric.data import DataLoader
from torch_geometric.nn import GCNConv, global_mean_pool
import torch.nn.functional as F
import pandas as pd
import random as rd
import os
from rdkit import Chem
from rdkit.Chem import rdmolops
from google.colab import drive
from torch_geometric.loader import DataLoader
from torch_geometric.data import Data
from sklearn.metrics import accuracy_score
import itertools

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Load the data
# This code cell connects to my previously connected private google drive and loads 1000 benign function call graphs and 1000 malicious ones from the artemis family, labels them accordingly and adds them to a list

# %%
def read_edgelist_to_graph(filepath, label):
    try:
        edge_index = []
        with open(filepath, 'r') as f:
            for line in f:
                if line.startswith('#'):
                    continue
                source, target = map(int, line.strip().split())
                edge_index.append([source, target])

        edge_index = torch.tensor(edge_index, dtype=torch.long).t().contiguous()
        x = torch.ones(edge_index.max().item() + 1, 1, dtype=torch.float)
        data = Data(x=x, edge_index=edge_index, y=label)
        return data
    except Exception as e:
        print(f"Error reading file {filepath}: {e}")
        return None

benign_dir = '/content/drive/My Drive/malnet/benign/'
artemis_dir = '/content/drive/My Drive/malnet/artemis/'

data_list = []

# Load graphs from the 'benign' directory
for filename in os.listdir(benign_dir):
    if filename.endswith(".edgelist"):
        filepath = os.path.join(benign_dir, filename)
        # label 0 is non malicious
        graph_data = read_edgelist_to_graph(filepath, 0)
        if graph_data:
            data_list.append(graph_data)
# Load graphs from the 'artemis' directory
for filename in os.listdir(artemis_dir):
    if filename.endswith(".edgelist"):
        filepath = os.path.join(artemis_dir, filename)
        # label 1 is malicious
        graph_data = read_edgelist_to_graph(filepath, 1)
        if graph_data:
            data_list.append(graph_data)

print(f"Loaded {len(data_list)} graphs.")
# Out:
# Loaded 2000 graphs.

# %% [markdown]
# ## Define a data loader

# %%
# Shuffle the data list
rd.shuffle(data_list)

# Define the split ratios
train_ratio = 0.8
val_ratio = 0.1
test_ratio = 0.1

# Calculate the split indices
train_size = int(len(data_list) * train_ratio)
val_size = int(len(data_list) * val_ratio)
test_size = len(data_list) - train_size - val_size

# Split the data
train_data = data_list[:train_size]
val_data = data_list[train_size:train_size + val_size]
test_data = data_list[train_size + val_size:]

# Create data loaders
train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
val_loader = DataLoader(val_data, batch_size=32, shuffle=False)
test_loader = DataLoader(test_data, batch_size=32, shuffle=False)

print(f"Train size: {len(train_data)}")
print(f"Validation size: {len(val_data)}")
print(f"Test size: {len(test_data)}")
# Out:
# Train size: 1600
# Validation size: 200
# Test size: 200

# %% [markdown]
# ## Evaluate different hyperparameter combination using gridsearch

# %%
class GNN(torch.nn.Module):
    def __init__(self, hidden_units, num_layers, dropout):
        super(GNN, self).__init__()

        self.num_layers = num_layers
        self.hidden_units = hidden_units

        self.layers = torch.nn.ModuleList()
        self.layers.append(GCNConv(1, hidden_units))

        for _ in range(num_layers - 1):
            self.layers.append(GCNConv(hidden_units, hidden_units))

        self.fc = torch.nn.Linear(hidden_units, 2)
        self.dropout = dropout

    def forward(self, data):
        edge_index = data.edge_index
        x = torch.zeros((data.num_nodes, 1)).to(edge_index.device)

        for i in range(self.num_layers):
            x = F.relu(self.layers[i](x, edge_index))
            x = F.dropout(x, p=self.dropout, training=self.training)

        # pool all nodes to perform graph level classification
        x = global_mean_pool(x, data.batch)
        x = self.fc(x)
        return x

# %%
def train_and_evaluate(model, train_loader, val_loader, optimizer, criterion, device, num_epochs=10):
    model.train()
    best_val_accuracy = 0

    for epoch in range(num_epochs):
        total_loss = 0
        correct = 0
        total = 0

        for data in train_loader:
            data = data.to(device)
            optimizer.zero_grad()
            output = model(data)

            if len(data.y.shape) > 1:
                _, target = data.y.max(dim=1)
            else:
                target = data.y

            loss = criterion(output, target)
            total_loss += loss.item()

            loss.backward()
            optimizer.step()

            _, predicted = output.max(dim=1)
            correct += predicted.eq(target).sum().item()
            total += data.num_graphs

        train_loss = total_loss / len(train_loader)
        train_accuracy = correct / total
        print(f"Epoch {epoch + 1}/{num_epochs} - Loss: {train_loss:.4f}, Accuracy: {train_accuracy:.4f}")

        val_accuracy = evaluate(model, val_loader, device)
        print(f"Validation Accuracy after Epoch {epoch + 1}: {val_accuracy:.4f}")

        if val_accuracy > best_val_accuracy:
            best_val_accuracy = val_accuracy

    return best_val_accuracy


def evaluate(model, val_loader, device):
    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for data in val_loader:
            data = data.to(device)
            output = model(data)

            target = data.y

            _, predicted = output.max(dim=1)
            correct += predicted.eq(target).sum().item()
            total += data.num_graphs

    val_accuracy = correct / total
    return val_accuracy

# %%
param_grid = {
    "lr": [0.0001, 0.001, 0.01],
    "num_layers": [2,3,4],
    "hidden_units": [8, 16, 32, 64],
    "dropout": [0.3, 0.5],
    "weight_decay": [1e-5, 1e-4]
}

best_model = None
best_score = -float('inf')
best_params = {}

# Perform grid search
for lr, num_layers, hidden_units, dropout, weight_decay in itertools.product(
    param_grid['lr'],
    param_grid['num_layers'],
    param_grid['hidden_units'],
    param_grid['dropout'],
    param_grid['weight_decay']
):
    model = GNN(hidden_units=hidden_units, num_layers=num_layers, dropout=dropout)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    criterion = torch.nn.CrossEntropyLoss()

    accuracy = train_and_evaluate(model, train_loader, val_loader, optimizer, criterion, device)

    print(f"Hyperparameters: lr={lr}, num_layers={num_layers}, hidden_units={hidden_units}, dropout={dropout}, weight_decay={weight_decay}")
    print(f"Validation Accuracy: {accuracy}")

    # If the current model has a better accuracy, store it
    if accuracy > best_score:
        best_score = accuracy
        best_model = model
        best_params = {
            "lr": lr,
            "num_layers": num_layers,
            "hidden_units": hidden_units,
            "dropout": dropout,
            "weight_decay": weight_decay
        }

# Output the best hyperparameters
print("Best Hyperparameters found:")
print(best_params)
# Out:
# Epoch 1/10 - Loss: 0.6938, Accuracy: 0.5075
# Validation Accuracy after Epoch 1: 0.4700
# Epoch 2/10 - Loss: 0.6938, Accuracy: 0.5075
# Validation Accuracy after Epoch 2: 0.4700
# Epoch 3/10 - Loss: 0.6937, Accuracy: 0.5075
# Validation Accuracy after Epoch 3: 0.4700
# Epoch 4/10 - Loss: 0.6937, Accuracy: 0.5075
# Validation Accuracy after Epoch 4: 0.4700
# Epoch 5/10 - Loss: 0.6936, Accuracy: 0.5075
# Validation Accuracy after Epoch 5: 0.4700
# Epoch 6/10 - Loss: 0.6936, Accuracy: 0.5075
# Validation Accuracy after Epoch 6: 0.4700
# Epoch 7/10 - Loss: 0.6936, Accuracy: 0.5075
# Validation Accuracy after Epoch 7: 0.4700
# Epoch 8/10 - Loss: 0.6936, Accuracy: 0.5075
# Validation Accuracy after Epoch 8: 0.4700
# Epoch 9/10 - Loss: 0.6935, Accuracy: 0.5075
# Validation Accuracy after Epoch 9: 0.4700
# Epoch 10/10 - Loss: 0.6935, Accuracy: 0.5075
# Validation Accuracy after Epoch 10: 0.4700
# Hyperparameters: lr=0.0001, num_layers=2, hidden_units=8, dropout=0.3, weight_decay=1e-05
# Validation Accuracy: 0.47
# Epoch 1/10 - Loss: 0.7309, Accuracy: 0.4925
# Validation Accuracy after Epoch 1: 0.5300
# Epoch 2/10 - Loss: 0.7297, Accuracy: 0.4925
# Validation Accuracy after Epoch 2: 0.5300
# Epoch 3/10 - Loss: 0.7286, Accuracy: 0.4925
# Validation Accuracy after Epoch 3: 0.5300
# Epoch 4/10 - Loss: 0.7275, Accuracy: 0.4925
# Validation Accuracy after Epoch 4: 0.5300
# Epoch 5/10 - Loss: 0.7264, Accuracy: 0.4925
# Validation Accuracy after Epoch 5: 0.5300
# Epoch 6/10 - Loss: 0.7254, Accuracy: 0.4925
# Validation Accuracy after Epoch 6: 0.5300
# Epoch 7/10 - Loss: 0.7244, Accuracy: 0.4925
# Validation Accuracy after Epoch 7: 0.5300
# Epoch 8/10 - Loss: 0.7234, Accuracy: 0.4925
# Validation Accuracy after Epoch 8: 0.5300
# Epoch 9/10 - Loss: 0.7225, Accuracy: 0.4925
# Validation Accuracy after Epoch 9: 0.5300
# Epoch 10/10 - Loss: 0.7215, Accuracy: 0.4925
# Validation Accuracy after Epoch 10: 0.5300
# Hyperparameters: lr=0.0001, num_layers=2, hidden_units=8, dropout=0.3, weight_decay=0.0001
# Validation Accuracy: 0.53
# Epoch 1/10 - Loss: 0.7288, Accuracy: 0.4925
# Validation Accuracy after Epoch 1: 0.5300
# Epoch 2/10 - Loss: 0.7277, Accuracy: 0.4925
# Validation Accuracy after Epoch 2: 0.5300
# Epoch 3/10 - Loss: 0.7266, Accuracy: 0.4925
# Validation Accuracy after Epoch 3: 0.5300
# Epoch 4/10 - Loss: 0.7256, Accuracy: 0.4925
# Validation Accuracy after Epoch 4: 0.5300
# Epoch 5/10 - Loss: 0.7246, Accuracy: 0.4925
# Validation Accuracy after Epoch 5: 0.5300
# Epoch 6/10 - Loss: 0.7236, Accuracy: 0.4925
# Validation Accuracy after Epoch 6: 0.5300
# Epoch 7/10 - Loss: 0.7226, Accuracy: 0.4925
# Validation Accuracy after Epoch 7: 0.5300
# Epoch 8/10 - Loss: 0.7216, Accuracy: 0.4925
# Validation Accuracy after Epoch 8: 0.5300
# Epoch 9/10 - Loss: 0.7207, Accuracy: 0.4925
# Validation Accuracy after Epoch 9: 0.5300
# Epoch 10/10 - Loss: 0.7199, Accuracy: 0.4925
# Validation Accuracy after Epoch 10: 0.5300
# Hyperparameters: lr=0.0001, num_layers=2, hidden_units=8, dropout=0.5, weight_decay=1e-05
# Validation Accuracy: 0.53
# Epoch 1/10 - Loss: 0.7102, Accuracy: 0.4925
# Validation Accuracy after Epoch 1: 0.5300
# Epoch 2/10 - Loss: 0.7096, Accuracy: 0.4925
# Validation Accuracy after Epoch 2: 0.5300
# Epoch 3/10 - Loss: 0.7090, Accuracy: 0.4925
# Validation Accuracy after Epoch 3: 0.5300
# Epoch 4/10 - Loss: 0.7084, Accuracy: 0.4925
# Validation Accuracy after Epoch 4: 0.5300
# Epoch 5/10 - Loss: 0.7078, Accuracy: 0.4925
# Validation Accuracy after Epoch 5: 0.5300
# Epoch 6/10 - Loss: 0.7072, Accuracy: 0.4925
# Validation Accuracy after Epoch 6: 0.5300
# Epoch 7/10 - Loss: 0.7066, Accuracy: 0.4925
# Validation Accuracy after Epoch 7: 0.5300
# Epoch 8/10 - Loss: 0.7061, Accuracy: 0.4925
# Validation Accuracy after Epoch 8: 0.5300
# Epoch 9/10 - Loss: 0.7056, Accuracy: 0.4925
# Validation Accuracy after Epoch 9: 0.5300
# Epoch 10/10 - Loss: 0.7051, Accuracy: 0.4925
# Validation Accuracy after Epoch 10: 0.5300
# Hyperparameters: lr=0.0001, num_layers=2, hidden_units=8, dropout=0.5, weight_decay=0.0001
# Validation Accuracy: 0.53
# Epoch 1/10 - Loss: 0.7053, Accuracy: 0.4925
# Validation Accuracy after Epoch 1: 0.5300
# Epoch 2/10 - Loss: 0.7049, Accuracy: 0.4925
# Validation Accuracy after Epoch 2: 0.5300
# Epoch 3/10 - Loss: 0.7044, Accuracy: 0.4925
# Validation Accuracy after Epoch 3: 0.5300
# Epoch 4/10 - Loss: 0.7039, Accuracy: 0.4925
# Validation Accuracy after Epoch 4: 0.5300
# Epoch 5/10 - Loss: 0.7035, Accuracy: 0.4925
# Validation Accuracy after Epoch 5: 0.5300
# Epoch 6/10 - Loss: 0.7031, Accuracy: 0.4925
# Validation Accuracy after Epoch 6: 0.5300
# Epoch 7/10 - Loss: 0.7026, Accuracy: 0.4925
# Validation Accuracy after Epoch 7: 0.5300
# Epoch 8/10 - Loss: 0.7022, Accuracy: 0.4925
# Validation Accuracy after Epoch 8: 0.5300
# Epoch 9/10 - Loss: 0.7019, Accuracy: 0.4925
# Validation Accuracy after Epoch 9: 0.5300
# Epoch 10/10 - Loss: 0.7015, Accuracy: 0.4925
# Validation Accuracy after Epoch 10: 0.5300
# Hyperparameters: lr=0.0001, num_layers=2, hidden_units=16, dropout=0.3, weight_decay=1e-05
# Validation Accuracy: 0.53
# Epoch 1/10 - Loss: 0.6981, Accuracy: 0.5075
# Validation Accuracy after Epoch 1: 0.4700
# Epoch 2/10 - Loss: 0.6978, Accuracy: 0.5075
# Validation Accuracy after Epoch 2: 0.4700
# Epoch 3/10 - Loss: 0.6976, Accuracy: 0.5075
# Validation Accuracy after Epoch 3: 0.4700
# Epoch 4/10 - Loss: 0.6974, Accuracy: 0.5075
# Validation Accuracy after Epoch 4: 0.4700
# Epoch 5/10 - Loss: 0.6972, Accuracy: 0.5075
# Validation Accuracy after Epoch 5: 0.4700
# Epoch 6/10 - Loss: 0.6970, Accuracy: 0.5075
# Validation Accuracy after Epoch 6: 0.4700
# Epoch 7/10 - Loss: 0.6968, Accuracy: 0.5075
# Validation Accuracy after Epoch 7: 0.4700
# Epoch 8/10 - Loss: 0.6966, Accuracy: 0.5075
# Validation Accuracy after Epoch 8: 0.4700
# Epoch 9/10 - Loss: 0.6964, Accuracy: 0.5075
# Validation Accuracy after Epoch 9: 0.4700
# Epoch 10/10 - Loss: 0.6962, Accuracy: 0.5075
# Validation Accuracy after Epoch 10: 0.4700
# Hyperparameters: lr=0.0001, num_layers=2, hidden_units=16, dropout=0.3, weight_decay=0.0001
# Validation Accuracy: 0.47
# Epoch 1/10 - Loss: 0.6936, Accuracy: 0.4925
# Validation Accuracy after Epoch 1: 0.5300
# Epoch 2/10 - Loss: 0.6936, Accuracy: 0.4925
# Validation Accuracy after Epoch 2: 0.5300
# Epoch 3/10 - Loss: 0.6935, Accuracy: 0.4925
# Validation Accuracy after Epoch 3: 0.5300
# Epoch 4/10 - Loss: 0.6935, Accuracy: 0.4925
# Validation Accuracy after Epoch 4: 0.5300
# Epoch 5/10 - Loss: 0.6935, Accuracy: 0.4925
# Validation Accuracy after Epoch 5: 0.5300
# Epoch 6/10 - Loss: 0.6934, Accuracy: 0.4925
# Validation Accuracy after Epoch 6: 0.5300
# Epoch 7/10 - Loss: 0.6934, Accuracy: 0.4925
# Validation Accuracy after Epoch 7: 0.5300
# Epoch 8/10 - Loss: 0.6934, Accuracy: 0.4925
# Validation Accuracy after Epoch 8: 0.5300
# Epoch 9/10 - Loss: 0.6934, Accuracy: 0.4925
# Validation Accuracy after Epoch 9: 0.5300
# Epoch 10/10 - Loss: 0.6934, Accuracy: 0.4925
# Validation Accuracy after Epoch 10: 0.5300
# Hyperparameters: lr=0.0001, num_layers=2, hidden_units=16, dropout=0.5, weight_decay=1e-05
# Validation Accuracy: 0.53
# Epoch 1/10 - Loss: 0.6946, Accuracy: 0.4925
# Validation Accuracy after Epoch 1: 0.5300
# Epoch 2/10 - Loss: 0.6946, Accuracy: 0.4925
# Validation Accuracy after Epoch 2: 0.5300
# Epoch 3/10 - Loss: 0.6945, Accuracy: 0.4925
# Validation Accuracy after Epoch 3: 0.5300
# Epoch 4/10 - Loss: 0.6944, Accuracy: 0.4925
# Validation Accuracy after Epoch 4: 0.5300
# Epoch 5/10 - Loss: 0.6943, Accuracy: 0.4925
# Validation Accuracy after Epoch 5: 0.5300
# Epoch 6/10 - Loss: 0.6943, Accuracy: 0.4925
# Validation Accuracy after Epoch 6: 0.5300
# Epoch 7/10 - Loss: 0.6942, Accuracy: 0.4925
# Validation Accuracy after Epoch 7: 0.5300
# Epoch 8/10 - Loss: 0.6941, Accuracy: 0.4925
# Validation Accuracy after Epoch 8: 0.5300
# Epoch 9/10 - Loss: 0.6941, Accuracy: 0.4925
# Validation Accuracy after Epoch 9: 0.5300
# Epoch 10/10 - Loss: 0.6940, Accuracy: 0.4925
# Validation Accuracy after Epoch 10: 0.5300
# Hyperparameters: lr=0.0001, num_layers=2, hidden_units=16, dropout=0.5, weight_decay=0.0001
# Validation Accuracy: 0.53
# Epoch 1/10 - Loss: 0.6934, Accuracy: 0.4925
# Validation Accuracy after Epoch 1: 0.5300
# Epoch 2/10 - Loss: 0.6933, Accuracy: 0.4925
# Validation Accuracy after Epoch 2: 0.5300
# Epoch 3/10 - Loss: 0.6933, Accuracy: 0.4925
# Validation Accuracy after Epoch 3: 0.5300
# Epoch 4/10 - Loss: 0.6933, Accuracy: 0.4925
# Validation Accuracy after Epoch 4: 0.5300
# Epoch 5/10 - Loss: 0.6933, Accuracy: 0.4925
# Validation Accuracy after Epoch 5: 0.5300
# Epoch 6/10 - Loss: 0.6933, Accuracy: 0.4925
# Validation Accuracy after Epoch 6: 0.5300
# Epoch 7/10 - Loss: 0.6933, Accuracy: 0.4925
# Validation Accuracy after Epoch 7: 0.5300
# Epoch 8/10 - Loss: 0.6933, Accuracy: 0.4925
# Validation Accuracy after Epoch 8: 0.5300
# Epoch 9/10 - Loss: 0.6933, Accuracy: 0.4925
# Validation Accuracy after Epoch 9: 0.5300
# Epoch 10/10 - Loss: 0.6932, Accuracy: 0.4925
# Validation Accuracy after Epoch 10: 0.5300
# Hyperparameters: lr=0.0001, num_layers=2, hidden_units=32, dropout=0.3, weight_decay=1e-05
# Validation Accuracy: 0.53
# Epoch 1/10 - Loss: 0.6930, Accuracy: 0.5075
# Validation Accuracy after Epoch 1: 0.4700
# Epoch 2/10 - Loss: 0.6930, Accuracy: 0.5075
# Validation Accuracy after Epoch 2: 0.4700
# Epoch 3/10 - Loss: 0.6930, Accuracy: 0.5075
# Validation Accuracy after Epoch 3: 0.4700
# Epoch 4/10 - Loss: 0.6930, Accuracy: 0.5075
# Validation Accuracy after Epoch 4: 0.4700
# Epoch 5/10 - Loss: 0.6930, Accuracy: 0.5075
# Validation Accuracy after Epoch 5: 0.4700
# Epoch 6/10 - Loss: 0.6930, Accuracy: 0.5075
# Validation Accuracy after Epoch 6: 0.4700
# Epoch 7/10 - Loss: 0.6930, Accuracy: 0.5075
# Validation Accuracy after Epoch 7: 0.4700
# Epoch 8/10 - Loss: 0.6930, Accuracy: 0.5075
# Validation Accuracy after Epoch 8: 0.4700
# Epoch 9/10 - Loss: 0.6930, Accuracy: 0.5075
# Validation Accuracy after Epoch 9: 0.4700
# Epoch 10/10 - Loss: 0.6930, Accuracy: 0.5075
# Validation Accuracy after Epoch 10: 0.4700
# Hyperparameters: lr=0.0001, num_layers=2, hidden_units=32, dropout=0.3, weight_decay=0.0001
# Validation Accuracy: 0.47
# Epoch 1/10 - Loss: 0.6952, Accuracy: 0.4925
# Validation Accuracy after Epoch 1: 0.5300
# Epoch 2/10 - Loss: 0.6951, Accuracy: 0.4925
# Validation Accuracy after Epoch 2: 0.5300
# Epoch 3/10 - Loss: 0.6950, Accuracy: 0.4925
# Validation Accuracy after Epoch 3: 0.5300
# Epoch 4/10 - Loss: 0.6949, Accuracy: 0.4925
# Validation Accuracy after Epoch 4: 0.5300
# Epoch 5/10 - Loss: 0.6948, Accuracy: 0.4925
# Validation Accuracy after Epoch 5: 0.5300
# Epoch 6/10 - Loss: 0.6947, Accuracy: 0.4925
# Validation Accuracy after Epoch 6: 0.5300
# Epoch 7/10 - Loss: 0.6946, Accuracy: 0.4925
# Validation Accuracy after Epoch 7: 0.5300
# Epoch 8/10 - Loss: 0.6945, Accuracy: 0.4925
# Validation Accuracy after Epoch 8: 0.5300
# Epoch 9/10 - Loss: 0.6944, Accuracy: 0.4925
# Validation Accuracy after Epoch 9: 0.5300
# Epoch 10/10 - Loss: 0.6944, Accuracy: 0.4925
# Validation Accuracy after Epoch 10: 0.5300
# Hyperparameters: lr=0.0001, num_layers=2, hidden_units=32, dropout=0.5, weight_decay=1e-05
# Validation Accuracy: 0.53
# Epoch 1/10 - Loss: 0.6940, Accuracy: 0.4925
# Validation Accuracy after Epoch 1: 0.5300
# Epoch 2/10 - Loss: 0.6939, Accuracy: 0.4925
# Validation Accuracy after Epoch 2: 0.5300
# Epoch 3/10 - Loss: 0.6939, Accuracy: 0.4925
# Validation Accuracy after Epoch 3: 0.5300
# Epoch 4/10 - Loss: 0.6938, Accuracy: 0.4925
# Validation Accuracy after Epoch 4: 0.5300
# Epoch 5/10 - Loss: 0.6938, Accuracy: 0.4925
# Validation Accuracy after Epoch 5: 0.5300
# Epoch 6/10 - Loss: 0.6938, Accuracy: 0.4925
# Validation Accuracy after Epoch 6: 0.5300
# Epoch 7/10 - Loss: 0.6937, Accuracy: 0.4925
# Validation Accuracy after Epoch 7: 0.5300
# Epoch 8/10 - Loss: 0.6937, Accuracy: 0.4925
# Validation Accuracy after Epoch 8: 0.5300
# Epoch 9/10 - Loss: 0.6936, Accuracy: 0.4925
# Validation Accuracy after Epoch 9: 0.5300
# Epoch 10/10 - Loss: 0.6936, Accuracy: 0.4925
# Validation Accuracy after Epoch 10: 0.5300
# Hyperparameters: lr=0.0001, num_layers=2, hidden_units=32, dropout=0.5, weight_decay=0.0001
# Validation Accuracy: 0.53
# Epoch 1/10 - Loss: 0.6935, Accuracy: 0.4925
# Validation Accuracy after Epoch 1: 0.5300
# Epoch 2/10 - Loss: 0.6934, Accuracy: 0.4925
# Validation Accuracy after Epoch 2: 0.5300
# Epoch 3/10 - Loss: 0.6934, Accuracy: 0.4925
# Validation Accuracy after Epoch 3: 0.5300
# Epoch 4/10 - Loss: 0.6934, Accuracy: 0.4925
# Validation Accuracy after Epoch 4: 0.5300
# Epoch 5/10 - Loss: 0.6934, Accuracy: 0.4925
# Validation Accuracy after Epoch 5: 0.5300
# Epoch 6/10 - Loss: 0.6934, Accuracy: 0.4925
# Validation Accuracy after Epoch 6: 0.5300
# Epoch 7/10 - Loss: 0.6933, Accuracy: 0.4925
# Validation Accuracy after Epoch 7: 0.5300
# Epoch 8/10 - Loss: 0.6933, Accuracy: 0.4925
# Validation Accuracy after Epoch 8: 0.5300
# Epoch 9/10 - Loss: 0.6933, Accuracy: 0.4925
# Validation Accuracy after Epoch 9: 0.5300
# Epoch 10/10 - Loss: 0.6933, Accuracy: 0.4925
# Validation Accuracy after Epoch 10: 0.5300
# Hyperparameters: lr=0.0001, num_layers=2, hidden_units=64, dropout=0.3, weight_decay=1e-05
# Validation Accuracy: 0.53
# Epoch 1/10 - Loss: 0.6960, Accuracy: 0.5075
# Validation Accuracy after Epoch 1: 0.4700
# Epoch 2/10 - Loss: 0.6958, Accuracy: 0.5075
# Validation Accuracy after Epoch 2: 0.4700
# Epoch 3/10 - Loss: 0.6957, Accuracy: 0.5075
# Validation Accuracy after Epoch 3: 0.4700
# Epoch 4/10 - Loss: 0.6955, Accuracy: 0.5075
# Validation Accuracy after Epoch 4: 0.4700
# Epoch 5/10 - Loss: 0.6954, Accuracy: 0.5075
# Validation Accuracy after Epoch 5: 0.4700
# Epoch 6/10 - Loss: 0.6953, Accuracy: 0.5075
# Validation Accuracy after Epoch 6: 0.4700
# Epoch 7/10 - Loss: 0.6952, Accuracy: 0.5075
# Validation Accuracy after Epoch 7: 0.4700
# Epoch 8/10 - Loss: 0.6951, Accuracy: 0.5075
# Validation Accuracy after Epoch 8: 0.4700
# Epoch 9/10 - Loss: 0.6949, Accuracy: 0.5075
# Validation Accuracy after Epoch 9: 0.4700
# Epoch 10/10 - Loss: 0.6948, Accuracy: 0.5075
# Validation Accuracy after Epoch 10: 0.4700
# Hyperparameters: lr=0.0001, num_layers=2, hidden_units=64, dropout=0.3, weight_decay=0.0001
# Validation Accuracy: 0.47
# Epoch 1/10 - Loss: 0.6947, Accuracy: 0.5075
# Validation Accuracy after Epoch 1: 0.4700
# Epoch 2/10 - Loss: 0.6946, Accuracy: 0.5075
# Validation Accuracy after Epoch 2: 0.4700
# Epoch 3/10 - Loss: 0.6946, Accuracy: 0.5075
# Validation Accuracy after Epoch 3: 0.4700
# Epoch 4/10 - Loss: 0.6945, Accuracy: 0.5075
# Validation Accuracy after Epoch 4: 0.4700
# Epoch 5/10 - Loss: 0.6944, Accuracy: 0.5075
# Validation Accuracy after Epoch 5: 0.4700
# Epoch 6/10 - Loss: 0.6943, Accuracy: 0.5075
# Validation Accuracy after Epoch 6: 0.4700
# Epoch 7/10 - Loss: 0.6942, Accuracy: 0.5075
# Validation Accuracy after Epoch 7: 0.4700
# Epoch 8/10 - Loss: 0.6942, Accuracy: 0.5075
# Validation Accuracy after Epoch 8: 0.4700
# Epoch 9/10 - Loss: 0.6941, Accuracy: 0.5075
# Validation Accuracy after Epoch 9: 0.4700
# Epoch 10/10 - Loss: 0.6941, Accuracy: 0.5075
# Validation Accuracy after Epoch 10: 0.4700
# Hyperparameters: lr=0.0001, num_layers=2, hidden_units=64, dropout=0.5, weight_decay=1e-05
# Validation Accuracy: 0.47
# Epoch 1/10 - Loss: 0.6931, Accuracy: 0.5075
# Validation Accuracy after Epoch 1: 0.4700
# Epoch 2/10 - Loss: 0.6931, Accuracy: 0.5075
# Validation Accuracy after Epoch 2: 0.4700
# Epoch 3/10 - Loss: 0.6931, Accuracy: 0.5075
# Validation Accuracy after Epoch 3: 0.4700
# Epoch 4/10 - Loss: 0.6931, Accuracy: 0.5075
# Validation Accuracy after Epoch 4: 0.4700
# Epoch 5/10 - Loss: 0.6931, Accuracy: 0.5075
# Validation Accuracy after Epoch 5: 0.4700
# Epoch 6/10 - Loss: 0.6931, Accuracy: 0.5075
# Validation Accuracy after Epoch 6: 0.4700
# Epoch 7/10 - Loss: 0.6931, Accuracy: 0.5075
# Validation Accuracy after Epoch 7: 0.4700
# Epoch 8/10 - Loss: 0.6931, Accuracy: 0.5075
# Validation Accuracy after Epoch 8: 0.4700
# Epoch 9/10 - Loss: 0.6931, Accuracy: 0.5075
# Validation Accuracy after Epoch 9: 0.4700
# Epoch 10/10 - Loss: 0.6931, Accuracy: 0.5075
# Validation Accuracy after Epoch 10: 0.4700
# Hyperparameters: lr=0.0001, num_layers=2, hidden_units=64, dropout=0.5, weight_decay=0.0001
# Validation Accuracy: 0.47
# Epoch 1/10 - Loss: 0.6933, Accuracy: 0.5075
# Validation Accuracy after Epoch 1: 0.4700
# Epoch 2/10 - Loss: 0.6933, Accuracy: 0.5075
# Validation Accuracy after Epoch 2: 0.4700
# Epoch 3/10 - Loss: 0.6933, Accuracy: 0.5075
# Validation Accuracy after Epoch 3: 0.4700
# Epoch 4/10 - Loss: 0.6933, Accuracy: 0.5075
# Validation Accuracy after Epoch 4: 0.4700
# Epoch 5/10 - Loss: 0.6933, Accuracy: 0.5075
# Validation Accuracy after Epoch 5: 0.4700
# Epoch 6/10 - Loss: 0.6932, Accuracy: 0.5075
# Validation Accuracy after Epoch 6: 0.4700
# Epoch 7/10 - Loss: 0.6932, Accuracy: 0.5075
# Validation Accuracy after Epoch 7: 0.4700
# Epoch 8/10 - Loss: 0.6932, Accuracy: 0.5075
# Validation Accuracy after Epoch 8: 0.4700
# Epoch 9/10 - Loss: 0.6932, Accuracy: 0.5075
# Validation Accuracy after Epoch 9: 0.4700
# Epoch 10/10 - Loss: 0.6932, Accuracy: 0.5075
# Validation Accuracy after Epoch 10: 0.4700
# Hyperparameters: lr=0.0001, num_layers=3, hidden_units=8, dropout=0.3, weight_decay=1e-05
# Validation Accuracy: 0.47
# Epoch 1/10 - Loss: 0.6938, Accuracy: 0.5075
# Validation Accuracy after Epoch 1: 0.4700
# Epoch 2/10 - Loss: 0.6938, Accuracy: 0.5075
# Validation Accuracy after Epoch 2: 0.4700
# Epoch 3/10 - Loss: 0.6937, Accuracy: 0.5075
# Validation Accuracy after Epoch 3: 0.4700
# Epoch 4/10 - Loss: 0.6937, Accuracy: 0.5075
# Validation Accuracy after Epoch 4: 0.4700
# Epoch 5/10 - Loss: 0.6936, Accuracy: 0.5075
# Validation Accuracy after Epoch 5: 0.4700
# Epoch 6/10 - Loss: 0.6936, Accuracy: 0.5075
# Validation Accuracy after Epoch 6: 0.4700
# Epoch 7/10 - Loss: 0.6936, Accuracy: 0.5075
# Validation Accuracy after Epoch 7: 0.4700
# Epoch 8/10 - Loss: 0.6935, Accuracy: 0.5075
# Validation Accuracy after Epoch 8: 0.4700
# Epoch 9/10 - Loss: 0.6935, Accuracy: 0.5075
# Validation Accuracy after Epoch 9: 0.4700
# Epoch 10/10 - Loss: 0.6935, Accuracy: 0.5075
# Validation Accuracy after Epoch 10: 0.4700
# Hyperparameters: lr=0.0001, num_layers=3, hidden_units=8, dropout=0.3, weight_decay=0.0001
# Validation Accuracy: 0.47
# Epoch 1/10 - Loss: 0.7025, Accuracy: 0.4925
# Validation Accuracy after Epoch 1: 0.5300
# Epoch 2/10 - Loss: 0.7021, Accuracy: 0.4925
# Validation Accuracy after Epoch 2: 0.5300
# Epoch 3/10 - Loss: 0.7017, Accuracy: 0.4925
# Validation Accuracy after Epoch 3: 0.5300
# Epoch 4/10 - Loss: 0.7014, Accuracy: 0.4925
# Validation Accuracy after Epoch 4: 0.5300
# Epoch 5/10 - Loss: 0.7010, Accuracy: 0.4925
# Validation Accuracy after Epoch 5: 0.5300
# Epoch 6/10 - Loss: 0.7007, Accuracy: 0.4925
# Validation Accuracy after Epoch 6: 0.5300
# Epoch 7/10 - Loss: 0.7003, Accuracy: 0.4925
# Validation Accuracy after Epoch 7: 0.5300
# Epoch 8/10 - Loss: 0.7000, Accuracy: 0.4925
# Validation Accuracy after Epoch 8: 0.5300
# Epoch 9/10 - Loss: 0.6997, Accuracy: 0.4925
# Validation Accuracy after Epoch 9: 0.5300
# Epoch 10/10 - Loss: 0.6994, Accuracy: 0.4925

# %% [markdown]
# ## Train the Model

# %% [markdown]
# ## Validation
